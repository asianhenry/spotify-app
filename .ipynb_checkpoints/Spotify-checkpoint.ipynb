# %%
import matplotlib.pyplot as plt
import pandas as pd
import requests
import spotipy
import scipy.stats as st
from scipy.optimize import curve_fit
import numpy as np

from config import credentials
# Import API key
from config import api_key
#from config import token

# %%
user_id='me'
kind='artists' #tracks
limit=50
token='BQCz8KXkF4_IDFtbQ8M43uVyggbl93HNPQ0ALYoC4Ep5Cql2PHUjNdZMq267GtgF_frHUnI627ikWJNT8Qb0PNgJWZIBDesOWhgYY8gCHnv0G1IwsMznJ2Dr7amzIjLpW6kPLRXxM3MBVgrBt2muAjBbUgVcdvYs6Jjve-_y11Wk7AuzuNIdQbhl8ll_9D5BZ3E2idfQ6lEAu8K2GCxSng-ldVmlnPSXtQsU1xfqTScPN0Me7CEobkuZnGBQbKKIsJTkI6xfy-nk26uo'


params={'time_range':'long_term','limit' : limit}
headers={"Accept": "application/json","Content-Type": "application/json","Authorization": 
         (f"Bearer {token}")}

#medium_term, short term

base_url=f'https://api.spotify.com/v1/{user_id}/top/{kind}?'#{api_key}'    #{timeframe}/{api_key}

# %%
#https://api.spotify.com/v1/me/top/artists?time_range=long_term&limit=20

# %%
user_data = requests.get(base_url,headers = headers,params=params).json()

artists=[]
genres=[]
popularity=[]
for i in range(limit):

    artists.append(user_data['items'][i]['name'])
    genres.append(user_data['items'][i]['genres'])
    popularity.append(user_data['items'][i]['popularity'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-6cd144a4a1e2> in <module>
#       6 for i in range(limit):
#       7
# ----> 8     artists.append(user_data['items'][i]['name'])
#       9     genres.append(user_data['items'][i]['genres'])
#      10     popularity.append(user_data['items'][i]['popularity'])
#
# KeyError: 'items'

# %%
user_data['items'][0]['genres']
# Out:
# ['k-pop']

# %%
top50_df=pd.DataFrame({'artist':artists,
                       'genres':genres,
                       'popularity':popularity})
top50_df
# Out:
#                   artist                                             genres  \
# 0                     IU                                            [k-pop]
# 1               RADWIMPS          [j-pop, j-rock, japanese emo, visual kei]
# 2                  TWICE                          [k-pop, k-pop girl group]
# 3                 EGOIST          [anime, anime rock, anime score, otacore]
# 4                GFRIEND                          [k-pop, k-pop girl group]
# 5             daigoro789        [japanese instrumental, otacore, scorecore]
# 6      Twenty One Pilots                                [modern rock, rock]
# 7     The Japanese House  [art pop, electropop, indie pop, indie poptimi...
# 8                 Grimes  [art pop, canadian electropop, chillwave, danc...
# 9           All Time Low             [modern rock, pop punk, post-teen pop]
# 10              CHVRCHES  [electropop, indie pop, indie poptimism, indie...
# 11                  LiSA                     [anime rock, j-pixie, otacore]
# 12                  MUNA  [art pop, dance pop, electropop, indie electro...
# 13           Bright Eyes  [anti-folk, indie folk, indie pop, indie rock,...
# 14  Manchester Orchestra  [dreamo, indie pop, indie rock, modern rock, s...
# 15  The Naked And Famous  [alternative dance, auckland indie, indie pop,...
# 16             Chairlift  [alternative dance, art pop, brooklyn indie, c...
# 17    Taking Back Sunday                                    [emo, pop punk]
# 18      Kero Kero Bonito  [art pop, escape room, future funk, hyperpop, ...
# 19                Metric  [alternative dance, canadian indie, canadian r...
# 20        Mr Twin Sister                 [art pop, chillwave, indietronica]
# 21             Relient K  [canadian ccm, christian alternative rock, chr...
# 22            Kanye West                        [chicago rap, hip hop, rap]
# 23         Mayday Parade  [emo, neon pop punk, pop emo, pop punk, pop rock]
# 24          Blood Orange  [alternative r&b, art pop, chillwave, electrop...
# 25              The Used            [emo, pop punk, post-hardcore, screamo]
# 26           Purity Ring  [art pop, canadian electropop, chillwave, edmo...
# 27            Wolf Alice  [art pop, english indie rock, indie rock, mode...
# 28           Bolbbalgan4                                [k-pop, korean pop]
# 29   Something Corporate  [emo, neon pop punk, piano rock, pop emo, pop ...
# 30                 SURAN                       [k-indie, k-pop, korean r&b]
# 31            Phantogram  [alternative dance, chillwave, electropop, ind...
# 32                  藤澤慶昌                                      [anime score]
# 33              Bon Iver  [eau claire indie, indie folk, melancholia, sl...
# 34        Tegan and Sara  [canadian indie, indie pop, indie poptimism, i...
# 35                Broods  [auckland indie, electropop, etherpop, indie e...
# 36                The xx               [downtempo, dream pop, indietronica]
# 37           Kishi Bashi  [indie pop, metropopolis, shimmer pop, stomp a...
# 38                 BANKS  [alternative r&b, art pop, dance pop, electrop...
# 39              Bastille         [metropopolis, modern rock, pop, pop rock]
# 40        Fickle Friends  [gauze pop, hopebeat, indie electropop, indie ...
# 41           Sylvan Esso  [art pop, electropop, etherpop, indie folk, in...
# 42          SILENT SIREN  [alt-idol, anime, anime rock, heavy alternativ...
# 43                   Wet  [alternative r&b, brooklyn indie, electropop, ...
# 44            Yerin Baek                       [k-indie, k-pop, korean pop]
# 45        London Grammar                   [metropopolis, nottingham indie]
# 46                  HAIM  [dance pop, indie pop, indietronica, metropopo...
# 47             St. Lucia  [alternative dance, electropop, indie pop, ind...
# 48              Paramore         [candy pop, emo, pixie, pop emo, pop punk]
# 49     Angels & Airwaves                    [emo, pop rock, socal pop punk]
#
#     popularity
# 0           78
# 1           76
# 2           84
# 3           59
# 4           66
# 5           62
# 6           87
# 7           65
# 8           73
# 9           75
# 10          74
# 11          73
# 12          58
# 13          64
# 14          61
# 15          63
# 16          49
# 17          65
# 18          62
# 19          62
# 20          50
# 21          61
# 22          91
# 23          67
# 24          68
# 25          67
# 26          61
# 27          60
# 28          69
# 29          50
# 30          62
# 31          63
# 32          37
# 33          77
# 34          63
# 35          64
# 36          72
# 37          56
# 38          67
# 39          82
# 40          51
# 41          66
# 42          49
# 43          61
# 44          64
# 45          70
# 46          72
# 47          57
# 48          79
# 49          63

# %%
#top50_df['genres'].value_counts
genres = pd.Series([x for item in top50_df.genres for x in item]).value_counts().reset_index()
genres=genres.rename(columns={'index':'genre',0:'count'})
genres.head(20)
#genre_list = genres['genre'].tolist()
#genre_list = sorted(genre_list)
#genre_list
#len(genre_list)
# Out:
#                 genre  count
# 0        indietronica     20
# 1           indie pop     17
# 2        metropopolis     16
# 3          electropop     14
# 4             art pop     11
# 5         shimmer pop     11
# 6         modern rock      9
# 7     indie poptimism      9
# 8            pop rock      8
# 9          vapor soul      8
# 10           pop punk      7
# 11         indie rock      7
# 12                emo      7
# 13                pop      6
# 14          chillwave      6
# 15              k-pop      6
# 16        escape room      5
# 17          dance pop      5
# 18  alternative dance      5
# 19       neo-synthpop      4

# %%
#genres['genre'] = genres['genre'].replace({'korean pop': 'k-pop',
#                                           'k-pop girl group':'k-pop',
#                                           'anime score':'anime',
#                                           'anime rock':'anime'})
top_genres=genres.iloc[:30,:]
#genres['count']

# %%
#use these columns for parameters for the pie chart
counts = top_genres['count']
genres = top_genres['genre']
#explode = 

#found a bunch of colors here
#https://matplotlib.org/3.1.0/gallery/color/named_colors.html
#colors = ["magenta","deepskyblue"]
#contruct plot
plt.figure(figsize = (5,5))
plt.pie(counts,labels=genres, autopct="%.1f%%", )
#plt.title("Mice Gender Distribution")
plt.axis("equal")
plt.show()

# %%
popularity_df=top50_df.sort_values('popularity',ascending=False)
popularity_df
# Out:
#                   artist                                             genres  \
# 22            Kanye West                        [chicago rap, hip hop, rap]
# 6      Twenty One Pilots                                [modern rock, rock]
# 2                  TWICE                          [k-pop, k-pop girl group]
# 39              Bastille         [metropopolis, modern rock, pop, pop rock]
# 48              Paramore         [candy pop, emo, pixie, pop emo, pop punk]
# 0                     IU                                            [k-pop]
# 33              Bon Iver  [eau claire indie, indie folk, melancholia, sl...
# 1               RADWIMPS          [j-pop, j-rock, japanese emo, visual kei]
# 9           All Time Low             [modern rock, pop punk, post-teen pop]
# 10              CHVRCHES  [electropop, indie pop, indie poptimism, indie...
# 8                 Grimes  [art pop, canadian electropop, chillwave, danc...
# 11                  LiSA                     [anime rock, j-pixie, otacore]
# 36                The xx               [downtempo, dream pop, indietronica]
# 46                  HAIM  [dance pop, indie pop, indietronica, metropopo...
# 45        London Grammar                   [metropopolis, nottingham indie]
# 28           Bolbbalgan4                                [k-pop, korean pop]
# 24          Blood Orange  [alternative r&b, art pop, chillwave, electrop...
# 38                 BANKS  [alternative r&b, art pop, dance pop, electrop...
# 23         Mayday Parade  [emo, neon pop punk, pop emo, pop punk, pop rock]
# 25              The Used            [emo, pop punk, post-hardcore, screamo]
# 4                GFRIEND                          [k-pop, k-pop girl group]
# 41           Sylvan Esso  [art pop, electropop, etherpop, indie folk, in...
# 17    Taking Back Sunday                                    [emo, pop punk]
# 7     The Japanese House  [art pop, electropop, indie pop, indie poptimi...
# 35                Broods  [auckland indie, electropop, etherpop, indie e...
# 44            Yerin Baek                       [k-indie, k-pop, korean pop]
# 13           Bright Eyes  [anti-folk, indie folk, indie pop, indie rock,...
# 31            Phantogram  [alternative dance, chillwave, electropop, ind...
# 34        Tegan and Sara  [canadian indie, indie pop, indie poptimism, i...
# 49     Angels & Airwaves                    [emo, pop rock, socal pop punk]
# 15  The Naked And Famous  [alternative dance, auckland indie, indie pop,...
# 30                 SURAN                       [k-indie, k-pop, korean r&b]
# 18      Kero Kero Bonito  [art pop, escape room, future funk, hyperpop, ...
# 19                Metric  [alternative dance, canadian indie, canadian r...
# 5             daigoro789        [japanese instrumental, otacore, scorecore]
# 14  Manchester Orchestra  [dreamo, indie pop, indie rock, modern rock, s...
# 21             Relient K  [canadian ccm, christian alternative rock, chr...
# 26           Purity Ring  [art pop, canadian electropop, chillwave, edmo...
# 43                   Wet  [alternative r&b, brooklyn indie, electropop, ...
# 27            Wolf Alice  [art pop, english indie rock, indie rock, mode...
# 3                 EGOIST          [anime, anime rock, anime score, otacore]
# 12                  MUNA  [art pop, dance pop, electropop, indie electro...
# 47             St. Lucia  [alternative dance, electropop, indie pop, ind...
# 37           Kishi Bashi  [indie pop, metropopolis, shimmer pop, stomp a...
# 40        Fickle Friends  [gauze pop, hopebeat, indie electropop, indie ...
# 29   Something Corporate  [emo, neon pop punk, piano rock, pop emo, pop ...
# 20        Mr Twin Sister                 [art pop, chillwave, indietronica]
# 42          SILENT SIREN  [alt-idol, anime, anime rock, heavy alternativ...
# 16             Chairlift  [alternative dance, art pop, brooklyn indie, c...
# 32                  藤澤慶昌                                      [anime score]
#
#     popularity
# 22          91
# 6           87
# 2           84
# 39          82
# 48          79
# 0           78
# 33          77
# 1           76
# 9           75
# 10          74
# 8           73
# 11          73
# 36          72
# 46          72
# 45          70
# 28          69
# 24          68
# 38          67
# 23          67
# 25          67
# 4           66
# 41          66
# 17          65
# 7           65
# 35          64
# 44          64
# 13          64
# 31          63
# 34          63
# 49          63
# 15          63
# 30          62
# 18          62
# 19          62
# 5           62
# 14          61
# 21          61
# 26          61
# 43          61
# 27          60
# 3           59
# 12          58
# 47          57
# 37          56
# 40          51
# 29          50
# 20          50
# 42          49
# 16          49
# 32          37

# %%
mean_pop=popularity_df.mean()
print(popularity_df.mean())
# Out:
# popularity    65.5
# dtype: float64

# %%
monthly_listen=[31136355,19892244,5786789,19696892,8810802,4920540,6070574,2326642,4342067,7287210,2764446,2604646,
                4348878,4560359,2807877,1711729,2132838,2207593,1977451,1904265,999429,1423244,1654735,1925133,
               1445701,945814,1793936,1461294,1458824,820964,1734413,855722,783786,1184485,559604,928138,1055185,
               853462,1420310,1021964,436136,869287,896391,678255,307237,304716,374888,106790,337555,12476]

# %%
len(monthly_listen)
# Out:
# 50

# %%
poppy=popularity_df['popularity'].tolist()

pops=[97,95,91,95,84,89,89,73,83,87,89,91,86,78,86]
listens=[60696365,55170241,41987269,48867520,21692661,21024536,21487306,7642605,1704122,24823631,
        19651875,35018530,15602696,7057663,28074532]

poppy=poppy+pops
monthly_listen=monthly_listen+listens

x_axis=poppy
y_axis=monthly_listen
len(y_axis)
# Out:
# 65

# %%
https://open.spotify.com/artist/6S2OmqARrzebs0tKUEyXyp?si=NHujpOOmS_i08KhJARSZEg

# %%
def exponential(x, a, b):
    return a*np.exp(b*x)

# %%
pars, cov = curve_fit(f=exponential, xdata=x_axis, ydata=y_axis, p0=[0, 0], bounds=(-np.inf, np.inf))

# %%
x1=np.arange(min(poppy),max(poppy)+1,1)
line_1 = pars[0]*np.exp(pars[1]*x1)

# %%
listeners=pars[0]*np.exp(pars[1]*mean_pop)
int(round(listeners,0))

# %%
plt.figure(figsize=(10,7))
plt.yticks(np.arange(0,80000000,5000000))
plt.scatter(x_axis,y_axis)
plt.ylabel('Monthly Listeners\n')
plt.xlabel('\nPopularity')
ax = plt.gca()
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

plt.plot(mean_pop,listeners,markerfacecolor='red',marker="o",markersize=10)
plt.plot(x1, line_1, linestyle='--', linewidth=1, color='black')
plt.show()

# %%
# Out:
# 1769183
